# %% [markdown]
# <a href="https://colab.research.google.com/github/Ayeshaliaqut/Ayeshaliaqut/blob/main/opencv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-67c6d01a-9bab-4f8f-955d-a91d3e11b70a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-67c6d01a-9bab-4f8f-955d-a91d3e11b70a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
image = cv2.imread("exchange.jpg")
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(image)

# %%
resized = cv2.resize(image, (256, 256))

# %%
import cv2
import matplotlib.pyplot as plt

gray = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)

plt.imshow(gray, cmap='gray')
plt.axis('off')
plt.show()

# %%
blur = cv2.GaussianBlur(image, (5,5), 0)
plt.imshow(blur)
plt.axis('off')

# %%
import numpy as np
kernel = np.array([[0,-1,0],[-1,5,-1],[0,-1,0]])
sharp = cv2.filter2D(image, -1, kernel)
plt.imshow(sharp)
plt.axis('off')

# %%
bright = cv2.convertScaleAbs(image, alpha=1.3, beta=40)
plt.imshow(bright)
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(152.5), np.float64(147.5), np.float64(-0.5))

# %%
import cv2
import matplotlib.pyplot as plt

flip_h = cv2.flip(image, 1)

plt.figure(figsize=(5, 8))

plt.imshow(flip_h)
plt.axis('off')
plt.show()
